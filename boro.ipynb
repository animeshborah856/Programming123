# %% [markdown]
# <a href="https://colab.research.google.com/github/animeshborah856/Programming123/blob/main/boro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello")
# Out:
# Hello

# %%
num = int(input("Enter a number: "))

print("The number is:", num)
# Out:
# Enter a number: 7
# The number is: 7
